# %%
import pandas as pd

# %%
df=pd.ExcelFile(r"C:\Users\ksaat\Documents\frooti\data.xlsx")

# %%
sheet_1=pd.read_excel(r"C:\Users\ksaat\Documents\frooti\data.xlsx",sheet_name=0)

# %%
read_sheets_name=df.sheet_names
read_sheets_name
# Out:
# ['info', 'Instructions-1', 'Instruction-2', 'Assignment-2']

# %%
sheet_1
# Out:
#             Date    product        phase campaign_platform campaign_type  \
# 0     2019-10-16  Product 1  Performance        Google Ads        Search
# 1     2019-10-16  Product 1  Performance        Google Ads        Search
# 2     2019-10-16  Product 1  Performance        Google Ads        Search
# 3     2019-10-16  Product 1  Performance        Google Ads        Search
# 4     2019-10-18  Product 1  Performance        Google Ads        Search
# ...          ...        ...          ...               ...           ...
# 16829 2020-07-07  Product 1  Performance        Google Ads        Search
# 16830 2020-07-07  Product 1  Performance        Google Ads        Search
# 16831 2020-07-07  Product 1  Performance        Google Ads        Search
# 16832 2020-07-07  Product 1  Performance        Google Ads        Search
# 16833 2020-07-07  Product 1  Performance        Google Ads        Search
#
#       communication_medium subchannel audience_type creative_type  \
# ...

# %%
sheet_1.head()
# Out:
#         Date    product        phase campaign_platform campaign_type  \
# 0 2019-10-16  Product 1  Performance        Google Ads        Search
# 1 2019-10-16  Product 1  Performance        Google Ads        Search
# 2 2019-10-16  Product 1  Performance        Google Ads        Search
# 3 2019-10-16  Product 1  Performance        Google Ads        Search
# 4 2019-10-18  Product 1  Performance        Google Ads        Search
#
#   communication_medium subchannel audience_type creative_type creative_name  \
# 0      Search Keywords      Brand            '-            '-            '-
# 1      Search Keywords      Brand            '-            '-            '-
# 2      Search Keywords      Brand            '-            '-            '-
# 3      Search Keywords      Brand            '-            '-            '-
# 4      Search Keywords      Brand            '-            '-            '-
#
#     device           age  spends  impressions  clicks  link_clicks
# ...

# %%
sheet_1.tail()
# Out:
#             Date    product        phase campaign_platform campaign_type  \
# 16829 2020-07-07  Product 1  Performance        Google Ads        Search
# 16830 2020-07-07  Product 1  Performance        Google Ads        Search
# 16831 2020-07-07  Product 1  Performance        Google Ads        Search
# 16832 2020-07-07  Product 1  Performance        Google Ads        Search
# 16833 2020-07-07  Product 1  Performance        Google Ads        Search
#
#       communication_medium subchannel audience_type creative_type  \
# 16829      Search Keywords      Brand            '-            '-
# 16830      Search Keywords      Brand            '-            '-
# 16831      Search Keywords      Brand            '-            '-
# 16832      Search Keywords      Brand            '-            '-
# 16833      Search Keywords      Brand            '-            '-
#
#       creative_name  device           age  spends  impressions  clicks  \
# ...

# %%
sheet_1[:]
# Out:
#             Date    product        phase campaign_platform campaign_type  \
# 0     2019-10-16  Product 1  Performance        Google Ads        Search
# 1     2019-10-16  Product 1  Performance        Google Ads        Search
# 2     2019-10-16  Product 1  Performance        Google Ads        Search
# 3     2019-10-16  Product 1  Performance        Google Ads        Search
# 4     2019-10-18  Product 1  Performance        Google Ads        Search
# ...          ...        ...          ...               ...           ...
# 16829 2020-07-07  Product 1  Performance        Google Ads        Search
# 16830 2020-07-07  Product 1  Performance        Google Ads        Search
# 16831 2020-07-07  Product 1  Performance        Google Ads        Search
# 16832 2020-07-07  Product 1  Performance        Google Ads        Search
# 16833 2020-07-07  Product 1  Performance        Google Ads        Search
#
#       communication_medium subchannel audience_type creative_type  \
# ...

# %%
sheet_1[0:6]
# Out:
#         Date    product        phase campaign_platform campaign_type  \
# 0 2019-10-16  Product 1  Performance        Google Ads        Search
# 1 2019-10-16  Product 1  Performance        Google Ads        Search
# 2 2019-10-16  Product 1  Performance        Google Ads        Search
# 3 2019-10-16  Product 1  Performance        Google Ads        Search
# 4 2019-10-18  Product 1  Performance        Google Ads        Search
# 5 2019-10-18  Product 1  Performance        Google Ads        Search
#
#   communication_medium subchannel audience_type creative_type creative_name  \
# 0      Search Keywords      Brand            '-            '-            '-
# 1      Search Keywords      Brand            '-            '-            '-
# 2      Search Keywords      Brand            '-            '-            '-
# 3      Search Keywords      Brand            '-            '-            '-
# 4      Search Keywords      Brand            '-            '-            '-
# ...

# %%
sheet_1.shape
# Out:
# (16834, 16)

# %%
#explorative data analysis 
#identifying categorical and continois variables
#categorical variables are stored as 'object' and continous variables as either 'float64'
sheet_1.dtypes
# Out:
# Date                    datetime64[ns]
# product                         object
# phase                           object
# campaign_platform               object
# campaign_type                   object
# communication_medium            object
# subchannel                      object
# audience_type                   object
# creative_type                   object
# creative_name                   object
# device                          object
# age                             object
# spends                         float64
# impressions                      int64
# clicks                           int64
# link_clicks                    float64
# dtype: object

# %%
#univariate analysis of continous variables
sheet_1.describe()
# Out:
#              spends   impressions        clicks   link_clicks
# count  16834.000000  16834.000000  16834.000000  16288.000000
# mean     148.694236    287.959190     11.977783      2.170371
# std      483.895724   2444.450313     44.796963     18.659132
# min        0.000000      0.000000      0.000000      0.000000
# 25%        0.180000      3.000000      0.000000      0.000000
# 50%       22.535000     13.000000      2.000000      0.000000
# 75%      110.020000     64.000000      8.000000      0.000000
# max     9221.960000  67454.000000   1075.000000    450.000000

# %%
#plotting histogram of the clicks variable
sheet_1['clicks'].plot.hist()

# %%
#plotting the boxplot for the impressions variable
sheet_1['impressions'].plot.box()

# %%
sheet_1['clicks'].plot.box()

# %%
#univarariate analysis for categorical variables
sheet_1['clicks'].value_counts()
# Out:
# 0      4530
# 1      2821
# 2      1605
# 3      1119
# 4       759
#        ...
# 391       1
# 327       1
# 279       1
# 399       1
# 215       1
# Name: clicks, Length: 263, dtype: int64

# %%
#creating percentages from frequencies
sheet_1['clicks'].value_counts()/len(sheet_1['clicks'])
# Out:
# 0      0.269098
# 1      0.167578
# 2      0.095343
# 3      0.066473
# 4      0.045087
#          ...
# 391    0.000059
# 327    0.000059
# 279    0.000059
# 399    0.000059
# 215    0.000059
# Name: clicks, Length: 263, dtype: float64

# %%
#bar plot for clicks frequencies
sheet_1['clicks'].value_counts().plot.bar()

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
df.head(3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-9447ae629b41> in <module>
# ----> 1 df.head(3)
#
# NameError: name 'df' is not defined
