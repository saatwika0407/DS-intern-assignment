# %%
import pandas as pd

# %%
df=pd.ExcelFile(r"C:\Users\ksaat\Documents\frooti\data.xlsx")

# %%
read_sheets_name=df.sheet_names
read_sheets_name
# Out:
# ['info', 'Instructions-1', 'Instruction-2', 'Assignment-2']

# %%
df=pd.read_excel(r"C:\Users\ksaat\Documents\frooti\data.xlsx",sheet_name=3)

# %%
df.shape
# Out:
# (247, 367)

# %%
df.describe()
# Out:
#          2019-08-01    2019-08-02    2019-08-03    2019-08-04    2019-08-05  \
# count    247.000000    247.000000    247.000000    247.000000    247.000000
# mean    2129.437247   2108.971660   2138.493927   2131.704453   2117.008097
# std     6916.591567   6705.079257   6898.542138   6909.967202   6845.876214
# min        1.000000      1.000000      1.000000      1.000000      1.000000
# 25%       19.500000     19.500000     19.000000     20.000000     19.000000
# 50%      126.000000    127.000000    128.000000    129.000000    129.000000
# 75%     1414.500000   1421.000000   1400.000000   1416.500000   1377.000000
# max    83599.000000  79419.000000  82596.000000  83422.000000  82588.000000
#
#          2019-08-06    2019-08-07    2019-08-08    2019-08-09    2019-08-10  \
# count    247.000000    247.000000    247.000000    247.000000    247.000000
# mean    2112.712551   2134.327935   2144.991903   2118.846154   2118.607287
# ...

# %%
df.isnull().values.any()
# Out:
# False

# %%
import datetime

# %%
import numpy as np

# %%
df.shape
# Out:
# (247, 367)

# %%
df[1:]
# Out:
#            SKU  2019-08-01 00:00:00  2019-08-02 00:00:00  2019-08-03 00:00:00  \
# 1         3042                 2240                 2330                 2423
# 2         3086                  891                  909                  936
# 3         3155                 1628                 1628                 1563
# 4         3166                  369                  354                  343
# 5         8272                 1034                 1024                 1055
# ..         ...                  ...                  ...                  ...
# 242  PPAM11156                    2                    2                    2
# 243  PSTM01257                   22                   23                   24
# 244  PSTM01457                   14                   13                   12
# 245   WIM5011B                   92                   92                   91
# 246   WIM51234                    2                    2                    2
#
# ...

# %%
df.head()
# Out:
#     SKU  2019-08-01 00:00:00  2019-08-02 00:00:00  2019-08-03 00:00:00  \
# 0  2527                 1551                 1613                 1613
# 1  3042                 2240                 2330                 2423
# 2  3086                  891                  909                  936
# 3  3155                 1628                 1628                 1563
# 4  3166                  369                  354                  343
#
#    2019-08-04 00:00:00  2019-08-05 00:00:00  2019-08-06 00:00:00  \
# 0                 1532                 1517                 1441
# 1                 2350                 2374                 2398
# 2                  889                  880                  906
# 3                 1532                 1563                 1563
# 4                  340                  330                  337
#
#    2019-08-07 00:00:00  2019-08-08 00:00:00  2019-08-09 00:00:00  ...  \
# 0                 1383                 1424                 1381  ...
# ...

# %%
df.head(3)
# Out:
#     SKU  2019-08-01 00:00:00  2019-08-02 00:00:00  2019-08-03 00:00:00  \
# 0  2527                 1551                 1613                 1613
# 1  3042                 2240                 2330                 2423
# 2  3086                  891                  909                  936
#
#    2019-08-04 00:00:00  2019-08-05 00:00:00  2019-08-06 00:00:00  \
# 0                 1532                 1517                 1441
# 1                 2350                 2374                 2398
# 2                  889                  880                  906
#
#    2019-08-07 00:00:00  2019-08-08 00:00:00  2019-08-09 00:00:00  ...  \
# 0                 1383                 1424                 1381  ...
# 1                 2278                 2210                 2232  ...
# 2                  870                  879                  844  ...
#
#    2020-07-22 00:00:00  2020-07-23 00:00:00  2020-07-24 00:00:00  \
# 0                 1929                 1948                 1929
# ...

# %%
df=df.set_index('SKU')
df.head(3)
# Out:
#       2019-08-01  2019-08-02  2019-08-03  2019-08-04  2019-08-05  2019-08-06  \
# SKU
# 2527        1551        1613        1613        1532        1517        1441
# 3042        2240        2330        2423        2350        2374        2398
# 3086         891         909         936         889         880         906
#
#       2019-08-07  2019-08-08  2019-08-09  2019-08-10  ...  2020-07-22  \
# SKU                                                   ...
# 2527        1383        1424        1381        1340  ...        1929
# 3042        2278        2210        2232        2277  ...        7096
# 3086         870         879         844         852  ...         829
#
#       2020-07-23  2020-07-24  2020-07-25  2020-07-26  2020-07-27  2020-07-28  \
# SKU
# 2527        1948        1929        1987        2027        1926        1926
# 3042        7025        6955        6746        6881        6606        6804
# ...

# %%
df.index
# Out:
# Index([       2527,        3042,        3086,        3155,        3166,
#               8272,        9311,       13159,       13160,       14011,
#        ...
#        'PPAM05126', 'PPAM05156', 'PPAM06156', 'PPAM07156', 'PPAM08156',
#        'PPAM11156', 'PSTM01257', 'PSTM01457',  'WIM5011B',  'WIM51234'],
#       dtype='object', name='SKU', length=247)

# %%
df.loc['2019-08-06']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3.x\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '2019-08-06'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-18-f718c068c615> in <module>
# ----> 1 df.loc['2019-08-06']
#
# ...
